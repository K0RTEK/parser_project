# %%
import pandas as pd
import numpy as np
import nltk
from nltk.stem.snowball import SnowballStemmer
import re
import os
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\23mak\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_excel('Книга 2.xlsx')
df
# Out:
#                 Аспекты                                              Текст
# 0   Персональные данные  в Игре, в центре поддержки Пользователей, в но...
# 1   Персональные данные  Яндекс сохраняет указанные Пользователем данны...
# 2   Персональные данные  Персональные данные Пользователя обрабатываютс...
# 3   Персональные данные  Персональные данные Пользователя могут быть пе...
# 4   Персональные данные  Обработка персональных данных Пользователя осу...
# ..                  ...                                                ...
# 57  Персональные данные  Пользователь обязан при оформлении Заказа указ...
# 58  Персональные данные  Использование функций Сервиса/Приложения, в то...
# 59  Персональные данные  Пользователь обязан при оформлении Заказа указ...
# 60  Персональные данные  «закон о персональных данных» — Федеральный за...
# 61  Персональные данные  Соглашаясь с условиями настоящего Соглашения, ...
#
# [62 rows x 2 columns]

# %%
text = df['Текст']
text[0]
# Out:
# 'в Игре, в центре поддержки Пользователей, в новостном разделе Интернет-сайта Игры, на форумах, чатах и в тех разделах Интернет-сайта Игры, в которых Пользователь может оставлять текстовые сообщения, использовать соответствующий язык Интернет-сайта (язык соответствующей языковой зоны).\nсоблюдать условия настоящего Соглашения, включая Правила Игры, Лицензионное соглашение, без каких-либо ограничений;\nв момент регистрации в Игре на Ресурсе Steam указывать достоверную информацию;\nпредоставлять Правообладателю информацию обо всех будущих изменениях его регистрационных данных, включая, но не ограничиваясь изменением электронного адреса;\nне нарушать права интеллектуальной собственности Правообладателя в отношении Игры и/или каких-либо составляющих Игры и/или Ресурса Steam;\nсамостоятельно предпринимать соответствующие меры, обеспечивающие безопасность его учетных записей в Игре, паролей и предотвращающие несанкционированное пользование третьими лицами этими учетными записями; в случае,
# ...

# %%
### Разбиение текста на токены и стеминг(нахождение основы слова для заданного исходного слова.)
stemmer = SnowballStemmer("russian")

def token_and_stem(text):
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    for token in tokens:
        if re.search('[а-яА-Я]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

# %%
stopwords = nltk.corpus.stopwords.words('russian')
stopwords.extend(['что', 'это', 'так', 'вот', 'быть', 'как', 'в', 'к', 'на', 'при', 'т.ч', 'если', 'и/или', 'и/', 'ваш', 'или']) ### Расширение списка
print(stopwords)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'в
# ...

# %%
good_list = []
for i in range (62):
    good_words = []
    for word in token_and_stem(text[i]): 
        if word not in stopwords:
            print(word)
            good_words.append(word) 
    good_list.append(good_words)
# Out:
# игр
# центр
# поддержк
# пользовател
# новостн
# раздел
# интернет-сайт
# игр
# форум
# чат
# тех
# раздел
# интернет-сайт
# игр
# котор
# пользовател
# оставля
# текстов
# сообщен
# использова
# соответств
# язык
# интернет-сайт
# язык
# соответств
# языков
# зон
# соблюда
# услов
# настоя
# соглашен
# включ
# прав
# игр
# лицензион
# соглашен
# каких-либ
# ограничен
# момент
# регистрац
# игр
# ресурс
# указыва
# достоверн
# информац
# предоставля
# правообладател
# информац
# будущ
# изменен
# ег
# регистрацион
# дан
# включ
# ограничив
# изменен
# электрон
# адрес
# наруша
# прав
# интеллектуальн
# собствен
# правообладател
# отношен
# игр
# каких-либ
# составля
# игр
# ресурс
# самостоятельн
# предпринима
# соответств
# мер
# обеспечива
# безопасн
# ег
# учетн
# запис
# игр
# парол
# предотвраща
# несанкционирова
# пользован
# трет
# лиц
# эт
# учетн
# запис
# случа
# есл
# пользовател
# ест
# основан
# счита
# трет
# сторон
# получ
# дан
# информац
# ил
# могут
# получ
# долж
# ...

# %%
top_words = {}
for i in range (1000):
    try: 
        a = good_list[i]
        for y in a: 
            if y in top_words:
                top_words[y] += 1
            else:
                top_words[y] = 1 
    except:
        None
    
top_words
# Out:
# {'игр': 12,
#  'центр': 2,
#  'поддержк': 3,
#  'пользовател': 98,
#  'новостн': 2,
#  'раздел': 11,
#  'интернет-сайт': 5,
#  'форум': 2,
#  'чат': 1,
#  'тех': 4,
#  'котор': 18,
#  'оставля': 4,
#  'текстов': 2,
#  'сообщен': 10,
#  'использова': 11,
#  'соответств': 24,
#  'язык': 2,
#  'языков': 1,
#  'зон': 1,
#  'соблюда': 1,
#  'услов': 21,
#  'настоя': 18,
#  'соглашен': 25,
#  'включ': 18,
#  'прав': 28,
#  'лицензион': 2,
#  'каких-либ': 2,
#  'ограничен': 1,
#  'момент': 8,
#  'регистрац': 25,
#  'ресурс': 3,
#  'указыва': 4,
#  'достоверн': 9,
#  'информац': 52,
#  'предоставля': 19,
#  'правообладател': 12,
#  'будущ': 1,
#  'изменен': 12,
#  'ег': 15,
#  'регистрацион': 1,
#  'дан': 134,
#  'ограничив': 7,
#  'электрон': 9,
#  'адрес': 17,
#  'наруша': 3,
#  'интеллектуальн': 1,
#  'собствен': 7,
#  'отношен': 6,
#  'составля': 1,
#  'самостоятельн': 8,
#  'предпринима': 1,
#  'мер': 4,
#  'обеспечива': 4,
#  'безопасн': 5,
#  'учетн': 5,
#  'запис': 8,
#  'парол': 8,
# ...

# %%
{k: v for k, v in sorted(top_words.items(), key=lambda item: item[1], reverse = True)}
# Out:
# {'дан': 134,
#  'пользовател': 98,
#  'персональн': 84,
#  'сайт': 62,
#  'ил': 56,
#  'информац': 52,
#  'использован': 43,
#  'цел': 35,
#  'лиц': 34,
#  'предоставлен': 34,
#  'заказ': 34,
#  'указа': 32,
#  'прав': 28,
#  'такж': 27,
#  'обработк': 27,
#  'соглашен': 25,
#  'регистрац': 25,
#  'соответств': 24,
#  'сво': 24,
#  'номер': 24,
#  'доступ': 23,
#  'приложен': 23,
#  'услов': 21,
#  'есл': 21,
#  'соглас': 21,
#  'услуг': 20,
#  'предоставля': 19,
#  'числ': 19,
#  'получен': 19,
#  'котор': 18,
#  'настоя': 18,
#  'включ': 18,
#  'ин': 18,
#  'владельц': 18,
#  'телефон': 18,
#  'содержим': 18,
#  'адрес': 17,
#  'трет': 17,
#  'конфиденциальн': 17,
#  'карт': 17,
#  'действ': 16,
#  'товар': 16,
#  'ег': 15,
#  'обязательств': 15,
#  'явля': 15,
#  'исполнен': 14,
#  'друг': 14,
#  'пользовательск': 14,
#  'наш': 14,
#  'программ': 14,
#  'служб': 14,
#  'закон': 13,
#  'оператор': 13,
#  'заказчик': 13,
#  'игр': 12,
#  'правообладател': 12,
#  'изменен': 12,
# ...

# %%
###for k, v in top_words.items():
###    if v == 1:
###        del top_words[k]

# %%
good_list[0]
# Out:
# ['игр',
#  'центр',
#  'поддержк',
#  'пользовател',
#  'новостн',
#  'раздел',
#  'интернет-сайт',
#  'игр',
#  'форум',
#  'чат',
#  'тех',
#  'раздел',
#  'интернет-сайт',
#  'игр',
#  'котор',
#  'пользовател',
#  'оставля',
#  'текстов',
#  'сообщен',
#  'использова',
#  'соответств',
#  'язык',
#  'интернет-сайт',
#  'язык',
#  'соответств',
#  'языков',
#  'зон',
#  'соблюда',
#  'услов',
#  'настоя',
#  'соглашен',
#  'включ',
#  'прав',
#  'игр',
#  'лицензион',
#  'соглашен',
#  'каких-либ',
#  'ограничен',
#  'момент',
#  'регистрац',
#  'игр',
#  'ресурс',
#  'указыва',
#  'достоверн',
#  'информац',
#  'предоставля',
#  'правообладател',
#  'информац',
#  'будущ',
#  'изменен',
#  'ег',
#  'регистрацион',
#  'дан',
#  'включ',
#  'ограничив',
#  'изменен',
#  'электрон',
#  'адрес',
#  'наруша',
#  'прав',
#  'интеллектуальн',
#  'собствен',
#  'правообладател',
#  'отношен',
#  'игр',
#  'каких-либ',
#  'составля',
#  'игр',
#  'ресурс',
#  'самостоятельн',
# ...

# %%
for i in text[0]:
# Out:
# 'в Игре, в центре поддержки Пользователей, в новостном разделе Интернет-сайта Игры, на форумах, чатах и в тех разделах Интернет-сайта Игры, в которых Пользователь может оставлять текстовые сообщения, использовать соответствующий язык Интернет-сайта (язык соответствующей языковой зоны).\nсоблюдать условия настоящего Соглашения, включая Правила Игры, Лицензионное соглашение, без каких-либо ограничений;\nв момент регистрации в Игре на Ресурсе Steam указывать достоверную информацию;\nпредоставлять Правообладателю информацию обо всех будущих изменениях его регистрационных данных, включая, но не ограничиваясь изменением электронного адреса;\nне нарушать права интеллектуальной собственности Правообладателя в отношении Игры и/или каких-либо составляющих Игры и/или Ресурса Steam;\nсамостоятельно предпринимать соответствующие меры, обеспечивающие безопасность его учетных записей в Игре, паролей и предотвращающие несанкционированное пользование третьими лицами этими учетными записями; в случае,
# ...
